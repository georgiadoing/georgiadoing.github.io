# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a TSV of publications with metadata and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)). The core python code is also in `publications.py`. Run either from the `markdown_generator` folder after replacing `publications.tsv` with one containing your data.
#
# TODO: Make this work with BibTex and other databases of citations, rather than Stuart's non-standard TSV format and citation style.

# %% [markdown]
# ## Data format
#
# The TSV needs to have the following columns: pub_date, title, venue, excerpt, citation, site_url, and paper_url, with a header at the top.
#
# - `excerpt` and `paper_url` can be blank, but the others must have values.
# - `pub_date` must be formatted as YYYY-MM-DD.
# - `url_slug` will be the descriptive part of the .md file and the permalink URL for the page about the paper. The .md file will be `YYYY-MM-DD-[url_slug].md` and the permalink will be `https://[yourdomain]/publications/YYYY-MM-DD-[url_slug]`
#
# This is how the raw file looks (it doesn't look pretty, use a spreadsheet or other program to edit and create).

# %%
# !cat publications.tsv
# Out:
# pub_date	title	venue	excerpt	citation	url_slug	paper_url
# 2017-07-26	Unsupervised Extraction of Stable Expression Signatures from Public Compendia with an Ensemble of Neural Networks.	Cell Systems	This paper is about eADAGE.	"Tan J, Doing G, Lewis KA, Price CE, Chen KM, Cady KC, Perchuk B, Laub MT, Hogan
# DA, Greene CS. Unsupervised Extraction of Stable Expression Signatures from
# Public Compendia with an Ensemble of Neural Networks. Cell Syst. 2017 Jul
# 26;5(1):63-71.e6. doi: 10.1016/j.cels.2017.06.003. Epub 2017 Jul 12. PubMed
# [citation] PMID: 28711280, PMCID: PMC5532071"	Unsupervised-Extraction-of-Stable-Expression-Signatures-from-Public-Compendia-with-an-Ensemble-of-Neural-Networks	http://academicpages.github.io/files/Unsupervised Extraction of Stable Expression Signatures from Public Compendia with an Ensemble of Neural Networks.pdf
# 2018-01-04	"Draft Genome Sequence of a Violacein-Producing
# Iodobacter sp. from the Hudson Valley Watershed"	Genome Announcements	This paper is about strain BJB302.	"Doing G, Perron GG, Jude BA. Draft Genome Sequence of a Violacein-Producing Iodobacter sp. from the Hudson Valley Watershed. Genome Announc. 2018 Jan 4;6(1). pii:PMCID: PMC5754501 e01428-17. doi: 10.1128/genomeA.01428-17. PubMed [citation] PMID: 29301892, "	Draft-Genome-Sequence-of-a-Violacein-Producing-Iodobacter-sp.-from-the-Hudson-Valley-Watershed	http://academicpages.github.io/files/Draft Genome Sequence of a Violacein-Producing Iodobacter sp. from the Hudson Valley Watershed.pdf
# 2018-03-26	A Multimodal Strategy Used by a Large c-di-GMP Network	Journal of Bacteriology	This paper is about Pseudomonas DGC-PDE interactions.	"Dahlstrom KM, Collins AJ, Doing G, Taroni JN, Gauvin TJ, Greene CS, Hogan DA,
# O'Toole GA. A Multimodal Strategy Used by a Large c-di-GMP Network. J Bacteriol.
# 2018 Mar 26;200(8). pii: e00703-17. doi: 10.1128/JB.00703-17. Print 2018 Apr 15.
# PubMed [citation] PMID: 29311282, PMCID: PMC5869470"	A-Multimodal-Strategy-Used-by-a-Large-c-di-GMP-Network	http://academicpages.github.io/files/A Multimodal Strategy Used by a Large c-di-GMP Network.pdf
# 2018-01-18	"Genome Sequences of
# Phenotypically Distinct Janthinobacterium sp. Isolates Cultured from the Hudson
# Valley Watershed"	Genome Announcements	This paper is about strains from the BJB collection.	"Bettina AM, Doing G, O'Brien K, Perron GG, Jude BA. Draft Genome Sequences of
# Phenotypically Distinct Janthinobacterium sp. Isolates Cultured from the Hudson
# Valley Watershed. Genome Announc. 2018 Jan 18;6(3). pii: e01426-17. doi:
# 10.1128/genomeA.01426-17. PubMed [citation] PMID: 29348334, PMCID: PMC5773719"	Genome-Sequences-of-Phenotypically-Distinct-Janthinobacterium-sp.-Isolates-Cultured-from-the-Hudson-Valley-Watershed	http://academicpages.github.io/files/Draft Genome Sequences of Phenotypically Distinct Janthinobacterium sp. Isolates Cultured from the Hudson Valley Watershed.pdf
# 2018-07-03	"PathCORE-T: identifying and
# visualizing globally co-occurring pathways in large transcriptomic compendia"	BioData Mining	This paper is about gene set and pathway enrichment analysis.	"Chen KM, Tan J, Way GP, Doing G, Hogan DA, Greene CS. PathCORE-T: identifying and
# visualizing globally co-occurring pathways in large transcriptomic compendia.
# BioData Min. 2018 Jul 3;11:14. doi: 10.1186/s13040-018-0175-7. eCollection 2018.
# PubMed [citation] PMID: 29988723, PMCID: PMC6029133"	PathCORE-T:-identifying-and-visualizing-globally-co-occurring-pathways-in-large-transcriptomic-compendia	http://academicpages.github.io/PathCORE-T_ identifying and visualizing globally co-occurring pathways in large transcriptomic compendia.pdf
# 2019-05-22	"Ethanol Stimulates Trehalose Production through a SpoT-DksA-AlgU-Dependent
# Pathway in Pseudomonas aeruginosa"	Journal of Bacteriology	This paper is about the P. aeruginosa response to ethanol.	"Harty CE, Martins D, Doing G, Mould DL, Clay ME, Occhipinti P, Nguyen D, Hogan
# DA. Ethanol Stimulates Trehalose Production through a SpoT-DksA-AlgU-Dependent
# Pathway in Pseudomonas aeruginosa. J Bacteriol. 2019 May 22;201(12). pii:
# e00794-18. doi: 10.1128/JB.00794-18. Print 2019 Jun 15. PubMed [citation] PMID:
# 30936375, PMCID: PMC6531624"	Ethanol-Stimulates-Trehalose-Production-through-a-SpoT-DksA-AlgU-Dependent-Pathway-in-Pseudomonas-aeruginosa	http://academicpages.github.io/Ethanol Stimulates Trehalose Production through a SpoT-DksA-AlgU-Dependent Pathway in Pseudomonas aeruginosa.pdf
# 2020-08-19	"Conditional antagonism in
# co-cultures of Pseudomonas aeruginosa and Candida albicans: An intersection of
# ethanol and phosphate signaling distilled from dual-seq transcriptomics"	PLoS Genetics	This paper is about co-culture and dual-seq transcriptomics.	"Doing G, Koeppen K, Occipinti P, Harty CE, Hogan DA. Conditional antagonism in
# co-cultures of Pseudomonas aeruginosa and Candida albicans: An intersection of
# ethanol and phosphate signaling distilled from dual-seq transcriptomics. PLoS
# Genet. 2020 Aug 19;16(8):e1008783. doi: 10.1371/journal.pgen.1008783. eCollection
# 2020 Aug. PubMed [citation] PMID: 32813693, PMCID: PMC7480860"	Conditional-antagonism-in-co-cultures-of-Pseudomonas-aeruginosa-and-Candida-albicans:-An-intersection-of-ethanol-and-phosphate-signaling-distilled-from-dual-seq transcriptomics	http://academicpages.github.io/Conditional antagonism in co-cultures of Pseudomonas aeruginosa and Candida albicans_ An intersection of ethanol and phosphate signaling distilled from dual-seq transcriptomics.pdf
# 2020-11-03	"Correcting for experiment-specific
# variability in expression compendia can remove underlying signals"	Gigascience	This paper is about gene expression compendia.	"Lee AJ, Park Y, Doing G, Hogan DA, Greene CS. Correcting for experiment-specific
# variability in expression compendia can remove underlying signals. Gigascience.
# 2020 Nov 3;9(11). pii: giaa117. doi: 10.1093/gigascience/giaa117. PubMed
# [citation] PMID: 33140829, PMCID: PMC7607552"	Correcting-for-experiment-specific-variability-in-expression-compendia-can-remove-underlying-signals	http://academicpages.github.io/giaa117.pdf
# 2022-06-16	"CF-Seq, an accessible web application for rapid
# re-analysis of cystic fibrosis pathogen RNA sequencing studies"	Scientific Data	This paper is about development of an app for re-analysis of public data.	"Neff SL, Hampton TH, Puerner C, Cengher L, Doing G, Lee AJ, Koeppen K, Cheung AL,
# Hogan DA, Cramer RA, Stanton BA. CF-Seq, an accessible web application for rapid
# re-analysis of cystic fibrosis pathogen RNA sequencing studies. Sci Data. 2022
# Jun 16;9(1):343. doi: 10.1038/s41597-022-01431-1. PubMed [citation] PMID:
# 35710652, PMCID: PMC9203545"	"CF-Seq,-an-accessible-web-application-for-rapid-re-analysis-of-cystic-fibrosis-pathogen-RNA-sequencing-studies"	"http://academicpages.github.io/CF-Seq, an accessible web application for rapid re-analysis of cystic fibrosis pathogen RNA sequencing studies.pdf"
# 2022-08-10	"Using genome-wide
# expression compendia to study microorganisms"	Computational and Structural Biotechnology	This is a review.	"Lee AJ, Reiter T, Doing G, Oh J, Hogan DA, Greene CS. Using genome-wide
# expression compendia to study microorganisms. Comput Struct Biotechnol J. 2022
# Aug 10;20:4315-4324. doi: 10.1016/j.csbj.2022.08.012. eCollection 2022. Review.
# PubMed [citation] PMID: 36016717, PMCID: PMC9396250"	Using-genome-wide-expression-compendia-to-study-microorganisms	http://academicpages.github.io/Using genome-wide expression compendia to study microorganisms.pdf
# 2022-10-20	"SOPHIE: Generative Neural Networks Separate Common and Specific
# Transcriptional Responses"	Genomics Proteomics Bioinformatics	This paper is about simulating gene expression data.	"Lee AJ, Mould DL, Crawford J, Hu D, Powers RK, Doing G, Costello JC, Hogan DA,
# Greene CS. SOPHIE: Generative Neural Networks Separate Common and Specific
# Transcriptional Responses. Genomics Proteomics Bioinformatics. 2022
# Oct;20(5):912-927. doi: 10.1016/j.gpb.2022.09.011. Epub 2022 Oct 7. PubMed
# [citation] PMID: 36216026, PMCID: PMC10025681"	SOPHIE:-Generative-Neural-Networks-Separate-Common-and-Specific-Transcriptional-Responses. 	http://academicpages.github.io/SOPHIE_ Generative Neural Networks Separate Common and Specific Transcriptional Responses.pdf
# 2023-02-23	"Compendium-Wide Analysis
# of Pseudomonas aeruginosa Core and Accessory Genes Reveals Transcriptional
# Patterns across Strains PAO1 and PA14"	mSystems	This paper is about PAO1 and PA14 transcriptomics.	"Lee AJ, Doing G, Neff SL, Reiter T, Hogan DA, Greene CS. Compendium-Wide Analysis
# of Pseudomonas aeruginosa Core and Accessory Genes Reveals Transcriptional
# Patterns across Strains PAO1 and PA14. mSystems. 2023 Feb 23;8(1):e0034222. doi:
# 10.1128/msystems.00342-22. Epub 2022 Dec 21. PubMed [citation] PMID: 36541762,
# PMCID: PMC9948736"	Compendium-Wide-Analysis-of-Pseudomonas-aeruginosa-Core-and-Accessory-Genes-Reveals-Transcriptional-Patterns-across-Strains-PAO1-and-PA14	http://academicpages.github.io/Compendium-Wide Analysis of Pseudomonas aeruginosa Core and Accessory Genes Reveals Transcriptional Patterns across Strains PAO1 and PA14.pdf
# 2023-02-23	"Computationally Efficient Assembly of Pseudomonas aeruginosa Gene Expression
# Compendia"	mSystems	This paper is about compendia of microbial gene expression.	"Doing G, Lee AJ, Neff SL, Reiter T, Holt JD, Stanton BA, Greene CS, Hogan DA.
# Computationally Efficient Assembly of Pseudomonas aeruginosa Gene Expression
# Compendia. mSystems. 2023 Feb 23;8(1):e0034122. doi: 10.1128/msystems.00341-22.
# Epub 2022 Dec 21. PubMed [citation] PMID: 36541761, PMCID: PMC9948711"	Computationally-Efficient-Assembly-of-Pseudomonas-aeruginosa-Gene-Expression-Compendia	http://academicpages.github.io/Computationally Efficient Assembly of Pseudomonas aeruginosa Gene Expression Compendia.pdf
# 2024-04-02	Pseudomonas aeruginosa transcriptome analysis of metal restriction in ex vivo cystic fibrosis sputum	Microbiology Spectrum	This paper looks at P. aeruginosa gene expression in ex vivo sputum.	"Neff SL, Doing G, Reiter T, Hampton TH, Greene CS, Hogan DA. Pseudomonas aeruginosa transcriptome analysis of metal restriction in ex vivo cystic fibrosis sputum. Microbiol Spectr. 2024 Apr 2;12(4):e0315723. doi: 10.1128/spectrum.03157-23. Epub 2024 Feb 22. PMID: 38385740; PMCID: PMC10986534."	Pseudomonas-aeruginosa-transcriptome-analysis-of-metal-restriction-in-ex-vivo-cystic-fibrosis-sputum	http://academicpages.github.io/neff_and_doing-et-al-2024-pseudomonas-aeruginosa-transcriptome-analysis-of-metal-restriction-in-ex-vivo-cystic-fibrosis-sputum.pdf
# 2024-10-18	"E. PathDash, pathway activation analysis of publicly available pathogen gene expression data"	mSystems	This is a tool for the re-analysis of public gene expression datasets.	"Taub L, Hampton TH, Sarkar S, Doing G, Neff SL, Finger CE, Ferreira Fukutani K, Stanton BA.2024.E.PathDash, pathway activation analysis of publicly available pathogen gene expression data. mSystems9:e01030-24.https://doi.org/10.1128/msystems.01030-24"	E-PathDash-pathway-activation-analysis-of-publicly-available-pathogen-gene-expression-data	http://academicpages.github.io/taub-et-al-2024-e-pathdash-pathway-activation-analysis-of-publicly-available-pathogen-gene-expression-data.pdf
# 2024-12-01	TEAL-seq: Targeted Expression Analysis Sequencing	bioRxiv	This pre-print shares a method for targeted gene expression analysis in low-biomass samples.	"Doing G, Shanbhag P, Bell I, Cassidy S, Motakis E, Aiken E, Oh J, Adams MD. 2024. TEAL-seq: Targeted Expression Analysis Sequencing. bioRxiv 2024.11.26.625462."	TEAL-seq-Targeted-Expression-Analysis-Sequencing	http://academicpages.github.io/TEAL-seq.pdf

# %% [markdown]
# ## Import pandas
#
# We are using the very handy pandas library for dataframes.

# %%
import pandas as pd

# %% [markdown]
# ## Import TSV
#
# Pandas makes this easy with the read_csv function. We are using a TSV, so we specify the separator as a tab, or `\t`.
#
# I found it important to put this data in a tab-separated values format, because there are a lot of commas in this kind of data and comma-separated values can get messed up. However, you can modify the import statement, as pandas also has read_excel(), read_json(), and others.

# %%
publications = pd.read_csv("publications.tsv", sep="\t", header=0)
publications
# Out:
#       pub_date                                              title  \
# 0   2017-07-26  Unsupervised Extraction of Stable Expression S...
# 1   2018-01-04  Draft Genome Sequence of a Violacein-Producing...
# 2   2018-03-26  A Multimodal Strategy Used by a Large c-di-GMP...
# 3   2018-01-18  Genome Sequences of\nPhenotypically Distinct J...
# 4   2018-07-03  PathCORE-T: identifying and\nvisualizing globa...
# 5   2019-05-22  Ethanol Stimulates Trehalose Production throug...
# 6   2020-08-19  Conditional antagonism in\nco-cultures of Pseu...
# 7   2020-11-03  Correcting for experiment-specific \nvariabili...
# 8   2022-06-16  CF-Seq, an accessible web application for rapi...
# 9   2022-08-10  Using genome-wide\nexpression compendia to stu...
# 10  2022-10-20  SOPHIE: Generative Neural Networks Separate Co...
# 11  2023-02-23  Compendium-Wide Analysis\nof Pseudomonas aerug...
# 12  2023-02-23  Computationally Efficient Assembly of Pseudomo...
# 13  2024-04-02  Pseudomonas aeruginosa transcriptome analysis ...
# 14  2024-10-18  E. PathDash, pathway activation analysis of pu...
# 15  2024-12-01  TEAL-seq: Targeted Expression Analysis Sequencing
#
#                                          venue  \
# 0                                 Cell Systems
# 1                         Genome Announcements
# 2                      Journal of Bacteriology
# 3                         Genome Announcements
# 4                               BioData Mining
# 5                      Journal of Bacteriology
# 6                                PLoS Genetics
# 7                                  Gigascience
# 8                              Scientific Data
# 9   Computational and Structural Biotechnology
# 10          Genomics Proteomics Bioinformatics
# 11                                    mSystems
# 12                                    mSystems
# 13                       Microbiology Spectrum
# 14                                    mSystems
# 15                                     bioRxiv
#
#                                               excerpt  \
# 0                         This paper is about eADAGE.
# 1                  This paper is about strain BJB302.
# 2   This paper is about Pseudomonas DGC-PDE intera...
# 3   This paper is about strains from the BJB colle...
# 4   This paper is about gene set and pathway enric...
# 5   This paper is about the P. aeruginosa response...
# 6   This paper is about co-culture and dual-seq tr...
# 7      This paper is about gene expression compendia.
# 8   This paper is about development of an app for ...
# 9                                   This is a review.
# 10  This paper is about simulating gene expression...
# 11  This paper is about PAO1 and PA14 transcriptom...
# 12  This paper is about compendia of microbial gen...
# 13  This paper looks at P. aeruginosa gene express...
# 14  This is a tool for the re-analysis of public g...
# 15  This pre-print shares a method for targeted ge...
#
#                                              citation  \
# 0   Tan J, Doing G, Lewis KA, Price CE, Chen KM, C...
# 1   Doing G, Perron GG, Jude BA. Draft Genome Sequ...
# 2   Dahlstrom KM, Collins AJ, Doing G, Taroni JN, ...
# 3   Bettina AM, Doing G, O'Brien K, Perron GG, Jud...
# 4   Chen KM, Tan J, Way GP, Doing G, Hogan DA, Gre...
# 5   Harty CE, Martins D, Doing G, Mould DL, Clay M...
# 6   Doing G, Koeppen K, Occipinti P, Harty CE, Hog...
# 7   Lee AJ, Park Y, Doing G, Hogan DA, Greene CS. ...
# 8   Neff SL, Hampton TH, Puerner C, Cengher L, Doi...
# 9   Lee AJ, Reiter T, Doing G, Oh J, Hogan DA, Gre...
# 10  Lee AJ, Mould DL, Crawford J, Hu D, Powers RK,...
# 11  Lee AJ, Doing G, Neff SL, Reiter T, Hogan DA, ...
# 12  Doing G, Lee AJ, Neff SL, Reiter T, Holt JD, S...
# 13  Neff SL, Doing G, Reiter T, Hampton TH, Greene...
# 14  Taub L, Hampton TH, Sarkar S, Doing G, Neff SL...
# 15  Doing G, Shanbhag P, Bell I, Cassidy S, Motaki...
#
#                                              url_slug  \
# 0   Unsupervised-Extraction-of-Stable-Expression-S...
# 1   Draft-Genome-Sequence-of-a-Violacein-Producing...
# 2   A-Multimodal-Strategy-Used-by-a-Large-c-di-GMP...
# 3   Genome-Sequences-of-Phenotypically-Distinct-Ja...
# 4   PathCORE-T:-identifying-and-visualizing-global...
# 5   Ethanol-Stimulates-Trehalose-Production-throug...
# 6   Conditional-antagonism-in-co-cultures-of-Pseud...
# 7   Correcting-for-experiment-specific-variability...
# 8   CF-Seq,-an-accessible-web-application-for-rapi...
# 9   Using-genome-wide-expression-compendia-to-stud...
# 10  SOPHIE:-Generative-Neural-Networks-Separate-Co...
# 11  Compendium-Wide-Analysis-of-Pseudomonas-aerugi...
# 12  Computationally-Efficient-Assembly-of-Pseudomo...
# 13  Pseudomonas-aeruginosa-transcriptome-analysis-...
# 14  E-PathDash-pathway-activation-analysis-of-publ...
# 15   TEAL-seq-Targeted-Expression-Analysis-Sequencing
#
#                                             paper_url
# 0   http://academicpages.github.io/files/Unsupervi...
# 1   http://academicpages.github.io/files/Draft Gen...
# 2   http://academicpages.github.io/files/A Multimo...
# 3   http://academicpages.github.io/files/Draft Gen...
# 4   http://academicpages.github.io/PathCORE-T_ ide...
# 5   http://academicpages.github.io/Ethanol Stimula...
# 6   http://academicpages.github.io/Conditional ant...
# 7          http://academicpages.github.io/giaa117.pdf
# 8   http://academicpages.github.io/CF-Seq, an acce...
# 9   http://academicpages.github.io/Using genome-wi...
# 10  http://academicpages.github.io/SOPHIE_ Generat...
# 11  http://academicpages.github.io/Compendium-Wide...
# 12  http://academicpages.github.io/Computationally...
# 13  http://academicpages.github.io/neff_and_doing-...
# 14  http://academicpages.github.io/taub-et-al-2024...
# 15        http://academicpages.github.io/TEAL-seq.pdf

# %% [markdown]
# ## Escape special characters
#
# YAML is very picky about how it takes a valid string, so we are replacing single and double quotes (and ampersands) with their HTML encoded equivilents. This makes them look not so readable in raw format, but they are parsed and rendered nicely.

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %% [markdown]
# ## Creating the markdown files
#
# This is where the heavy lifting is done. This loops through all the rows in the TSV dataframe, then starts to concatentate a big string (```md```) that contains the markdown for each type. It does the YAML metadata first, then does the description for the individual page.

# %%
import os
for row, item in publications.iterrows():
    print(item.pub_date)
    md_filename = str(item.pub_date) + "-" + item.url_slug + ".md"
    html_filename = str(item.pub_date) + "-" + item.url_slug
    year = item.pub_date[:4]
    
    ## YAML variables
    
    md = "---\ntitle: \""   + item.title + '"\n'
    
    md += """collection: publications"""
    
    md += """\npermalink: /publication/""" + html_filename
    
    if len(str(item.excerpt)) > 5:
        md += "\nexcerpt: '" + html_escape(item.excerpt) + "'"
    
    md += "\ndate: " + str(item.pub_date) 
    
    md += "\nvenue: '" + html_escape(item.venue) + "'"
    
    if len(str(item.paper_url)) > 5:
        md += "\npaperurl: '" + item.paper_url + "'"
    
    md += "\ncitation: '" + html_escape(item.citation) + "'"
    
    md += "\n---"
    
    ## Markdown description for individual page
        
    if len(str(item.excerpt)) > 5:
        md += "\n" + html_escape(item.excerpt) + "\n"
    
    if len(str(item.paper_url)) > 5:
        md += "\n[Download paper here](" + item.paper_url + ")\n" 
        
    md += "\nRecommended citation: " + item.citation
    
    md_filename = os.path.basename(md_filename)
       
    with open("../_publications/" + md_filename, 'w') as f:
        f.write(md)
# Out:
# 2017-07-26
# 2018-01-04
# 2018-03-26
# 2018-01-18
# 2018-07-03
# 2019-05-22
# 2020-08-19
# 2020-11-03
# 2022-06-16
# 2022-08-10
# 2022-10-20
# 2023-02-23
# 2023-02-23
# 2024-04-02
# 2024-10-18
# 2024-12-01

# %% [markdown]
# These files are in the publications directory, one directory below where we're working from.

# %%
# !ls ../_publications/
# Out:
# 18-Draft-Genome-Sequence-of-a-Violacein-Producing-Iodobacter-sp.-from-the-Hudson-Valley-Watershed.md
# 18-PathCORE-T:-identifying-and-visualizing-globally-co-occurring-pathways-in-large-transcriptomic-compendia.md
# 20-Correcting-for-experiment-specific-variability-in-expression-compendia-can-remove-underlying-signals.md
# 2017-07-26-Unsupervised-Extraction-of-Stable-Expression-Signatures-from-Public-Compendia-with-an-Ensemble-of-Neural-Networks.md
# 2017-Unsupervised-Extraction-of-Stable-Expression-Signatures-from-Public-Compendia-with-an-Ensemble-of-Neural-Networks.md
# 2018-01-04-Draft-Genome-Sequence-of-a-Violacein-Producing-Iodobacter-sp.-from-the-Hudson-Valley-Watershed.md
# 2018-01-18-Genome-Sequences-of-Phenotypically-Distinct-Janthinobacterium-sp.-Isolates-Cultured-from-the-Hudson-Valley-Watershed.md
# 2018-03-26-A-Multimodal-Strategy-Used-by-a-Large-c-di-GMP-Network.md
# 2018-07-03-PathCORE-T:-identifying-and-visualizing-globally-co-occurring-pathways-in-large-transcriptomic-compendia.md
# 2018-A-Multimodal-Strategy-Used-by-a-Large-c-di-GMP-Network.md
# 2018-Genome-Sequences-of-Phenotypically-Distinct-Janthinobacterium-sp.-Isolates-Cultured-from-the-Hudson-Valley-Watershed.md
# 2019-05-22-Ethanol-Stimulates-Trehalose-Production-through-a-SpoT-DksA-AlgU-Dependent-Pathway-in-Pseudomonas-aeruginosa.md
# 2019-Ethanol-Stimulates-Trehalose-Production-through-a-SpoT-DksA-AlgU-Dependent-Pathway-in-Pseudomonas-aeruginosa.md
# 2020-08-19-Conditional-antagonism-in-co-cultures-of-Pseudomonas-aeruginosa-and-Candida-albicans:-An-intersection-of-ethanol-and-phosphate-signaling-distilled-from-dual-seq transcriptomics.md
# 2020-11-03-Correcting-for-experiment-specific-variability-in-expression-compendia-can-remove-underlying-signals.md
# 2020-Conditional-antagonism-in-co-cultures-of-Pseudomonas-aeruginosa-and-Candida-albicans:-An-intersection-of-ethanol-and-phosphate-signaling-distilled-from-dual-seq transcriptomics.md
# 2022-06-16-CF-Seq,-an-accessible-web-application-for-rapid-re-analysis-of-cystic-fibrosis-pathogen-RNA-sequencing-studies.md
# 2022-08-10-Using-genome-wide-expression-compendia-to-study-microorganisms.md
# 2022-10-20-SOPHIE:-Generative-Neural-Networks-Separate-Common-and-Specific-Transcriptional-Responses. .md
# 2022-CF-Seq,-an-accessible-web-application-for-rapid-re-analysis-of-cystic-fibrosis-pathogen-RNA-sequencing-studies.md
# 2022-SOPHIE:-Generative-Neural-Networks-Separate-Common-and-Specific-Transcriptional-Responses. .md
# 2023-02-23-Compendium-Wide-Analysis-of-Pseudomonas-aeruginosa-Core-and-Accessory-Genes-Reveals-Transcriptional-Patterns-across-Strains-PAO1-and-PA14.md
# 2023-02-23-Computationally-Efficient-Assembly-of-Pseudomonas-aeruginosa-Gene-Expression-Compendia.md
# 2023-Compendium-Wide-Analysis-of-Pseudomonas-aeruginosa-Core-and-Accessory-Genes-Reveals-Transcriptional-Patterns-across-Strains-PAO1-and-PA14.md
# 2023-Computationally-Efficient-Assembly-of-Pseudomonas-aeruginosa-Gene-Expression-Compendia.md
# 2024-04-02-Pseudomonas-aeruginosa-transcriptome-analysis-of-metal-restriction-in-ex-vivo-cystic-fibrosis-sputum.md
# 2024-10-18-E-PathDash-pathway-activation-analysis-of-publicly-available-pathogen-gene-expression-data.md
# 2024-12-01-TEAL-seq-Targeted-Expression-Analysis-Sequencing.md
# 22-Using-genome-wide-expression-compendia-to-study-microorganisms.md

# %%
# !cat ../_publications/17-Unsupervised-Extraction-of-Stable-Expression-Signatures-from-Public-Compendia-with-an-Ensemble-of-Neural-Networks.md
# Out:
# cat: ../_publications/17-Unsupervised-Extraction-of-Stable-Expression-Signatures-from-Public-Compendia-with-an-Ensemble-of-Neural-Networks.md: No such file or directory
